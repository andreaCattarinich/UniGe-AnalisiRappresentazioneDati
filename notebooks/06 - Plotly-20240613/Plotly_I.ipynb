# %% [markdown]
# #Introduzione a Plotly
#
#
# ---
#
# *Antonio Emanuele Cinà, Assistant Professor @ University of Genoa*
#
# **Analisi e Rappresentazione dei Dati** --
# 15 Aprile 2024
#
# ## Lezione 6: Plotly
#
#
# Materiale: https://tinyurl.com/ARD2024-L6

# %% [markdown]
# ![plotly.png](https://upload.wikimedia.org/wikipedia/commons/8/8a/Plotly-logo.png)

# %% [markdown]
# [Plotly](https://plotly.com/python/) è una libreria open-source per generare grafici **interattivi e dinamici** che supporta oltre 40 tipi di grafici unici che coprono un'ampia gamma di casi d'uso statistici, finanziari, geografici, scientifici e tridimensionali.
#
# Tra i tanti tipi di grafici che ci sono, ci si focalizzerà su:
#
# - Scatterplot, grafico di dispersione
#   - Bubblechart, diagramma a bolle
# - Linechart, grafico a linee
# - Barchart, grafico a barre
# - Histogram, istogramma
# - Piechart, grafico a torta
# - Tabelle con plotly
#
# **Dashboard Personalizzabili**
#
# Plotly non è solo una libreria per la creazione di grafici, ma consente anche di costruire e personalizzare dashboard interattivi. Le dashboard sono strumenti visuali potenti che permettono di rappresentare e analizzare dati in modo efficace. Utilizzando Plotly, è possibile integrare diversi tipi di grafici e visualizzazioni all'interno di una singola dashboard, consentendo agli utenti di esplorare e interagire con i dati in modi intuitivi e significativi.
#
# **Esempi di Dashboard:**
#
# - [Dashboard di Analisi Clinica](https://dash.gallery/dash-clinical-analytics/)
# - [Dashboard di Reionizzazione Cosmologica](https://heranow.reionization.org/)
#
# Questi esempi dimostrano come Plotly può essere utilizzato per creare dashboard altamente personalizzabili per una vasta gamma di applicazioni, dall'analisi clinica alla cosmologia. La flessibilità e le potenti funzionalità di Plotly consentono agli utenti di progettare e implementare soluzioni di visualizzazione dati adatte alle proprie esigenze specifiche.

# %% [markdown]
# ## Plotly Express

# %% [markdown]
# Il modulo `plotly.express` (di solito importato come `px`) contiene funzioni che utilizziamo per creare intere figure in una sola volta e viene chiamato Plotly Express o PX.
#
# **Vantaggi di Plotly Express:**
#
# - Implementa vari metodi per generare i grafici.
# - Si preoccupa di mettere i nomi agli assi e dare un primo stile.
# - Implementa già alcune funzioni interattive.
#
# Per utilizzare la libreria, già installata all'interno di Colab, la importiamo nel seguente modo:

# %%
import plotly.express as px

# %% [markdown]
# In generale un grafico viene creato nel seguente modo:
#
# ```
# fig = px.plotting_function(
#     dataframe,
#     x='column-for-xaxis',
#     y='column-for-yaxis',
#     title='Title For the Plot',
#     width=width_in_pixels,
#     height=height_in_pixels
# )
#
# fig.show()
# ```

# %% [markdown]
# Inoltre, Plotly fornisce diversi pandas dataframe di esempio, dei quali ne utilizzeremo alcuni durante la lezione per mostrare i vari grafici.
#
# In generale, i dataset possono essere trovati [qui](https://plotly.com/python-api-reference/generated/plotly.data.html).

# %% [markdown]
# # Scatterplot

# %% [markdown]
# Lo Scatterplot è un grafico che rappresenta i dati utilizzando punti su un piano cartesiano, dove ciascun punto rappresenta un'osservazione. È utile per identificare relazioni o tendenze tra due variabili, come correlazioni o cluster di dati.

# %% [markdown]
# Riportiamo qui alcuni esempi dove lo scatterplot può risultare utile:
#
# - **Correlazione tra il tempo di studio e il punteggio degli esami**:
#
#   In un dataset che contiene il tempo medio di studio settimanale e i punteggi degli esami di diversi studenti, uno scatterplot può essere utilizzato per visualizzare la relazione tra queste due variabili. Ogni punto nello scatterplot rappresenta uno studente, dove sull'asse x è riportato il tempo medio di studio e sull'asse y il punteggio dell'esame. Questo scatterplot può aiutare a identificare se esiste una correlazione tra il tempo di studio e i risultati degli esami.
#
# - **Distribuzione dei prezzi delle abitazioni in base alla dimensione**:
#
#   In un dataset immobiliare contenente informazioni sulle dimensioni delle abitazioni e i relativi prezzi, uno scatterplot può essere utilizzato per visualizzare la relazione tra la dimensione dell'abitazione (in metri quadrati) e il prezzo di vendita. Ogni punto nello scatterplot rappresenta una casa, dove sull'asse x è riportata la dimensione dell'abitazione e sull'asse y il prezzo di vendita. Questo scatterplot può aiutare a identificare se esiste una tendenza tra la dimensione dell'abitazione e il prezzo di vendita.
#
# - **Clustering dei clienti in base al reddito e alla spesa**:
#
#   In un dataset relativo ai clienti di un centro commerciale contenente informazioni sul reddito annuo e la spesa media mensile, uno scatterplot può essere utilizzato per visualizzare la relazione tra queste due variabili. Ogni punto nello scatterplot rappresenta un cliente, dove sull'asse x è riportato il reddito annuo e sull'asse y la spesa media mensile. Questo scatterplot può aiutare a identificare cluster di clienti con caratteristiche simili di reddito e spesa, utili per strategie di marketing mirate.

# %% [markdown]
# Creare uno [scatterplot](https://plotly.com/python/line-and-scatter/) con Plotly Express è molto facile. Infatti ci basterà utilizzare il metodo `px.scatter()` per crearne uno.
#
# Per questo esempio, utilizziamo il dataset IRIS interno a Plotly, noto per contenere informazioni riguardo a tre tipi di fiori: *setosa*, *versicolor* e *virginica*. Ogni campione nel dataset IRIS contiene le seguenti informazioni:
#
# - Lunghezza del sepalo (in cm)
# - Larghezza del sepalo (in cm)
# - Lunghezza del petalo (in cm)
# - Larghezza del petalo (in cm)
# - Specie di fiore (setosa, versicolor o virginica)
#
# Nel nostro esempio, ci concentreremo sulla relazione tra la larghezza e la lunghezza dei sepali dei fiori nel dataset IRIS. Questa analisi ci consentirà di esplorare se esiste una correlazione o un pattern tra queste due caratteristiche distintive dei fiori. Utilizzeremo Plotly per visualizzare i dati in modo interattivo e per esaminare eventuali relazioni o tendenze presenti nel dataset IRIS.

# %% [markdown]
# ![iris-machinelearning.png](data:image/png;base64,...)

# %%
import plotly.express as px
df = px.data.iris()

df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1
# 3           4.6          3.1           1.5          0.2  setosa           1
# 4           5.0          3.6           1.4          0.2  setosa           1

# %%
fig = px.scatter(df, x="sepal_width", y="sepal_length")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(df, x="sepal_width", y="sepal_length", width=800, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Possiamo colorare i punti dello scatterplot utilizzando il parametro `color=` e cambiare il tipo di marker con `symbol=`.
#
# Passando una variabile **categoriale**, come la 'species', plotly si preoccuperà di creare una legenda con i colori.
#
#  Altrimenti passando una variabile **continua**, come 'petal_length, verrà creata una leggenda con un gradiente di colori per specificare quanto più o meno grandi sono.

# %%
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", symbol="species",
                 title="Scatterplot variabile CATEGORIALE", width=800, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - `df`: Questo parametro indica il DataFrame (df) che contiene i dati da visualizzare nello scatterplot.
#
# - `x="sepal_width"`: Specifica che sull'asse x dello scatterplot verrà rappresentata la variabile "sepal_width"
#
# - `y="sepal_length"`: Indica che sull'asse y dello scatterplot verrà rappresentata la variabile "sepal_length"
#
# - `color="species"`: Questo parametro specifica che i punti nello scatterplot verranno colorati in base alla variabile "species"
#
# - `symbol="species"`: Questo parametro specifica che i punti nello scatterplot avranno un simbolo diverso in base alla variabile "species".
#
# - `title="Scatterplot variabile CATEGORIALE"`: Qui viene specificato il titolo del grafico.

# %%
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="petal_length", title="Scatterplot variabile CONTINUA", width=800, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Bubblechart

# %% [markdown]
# Il **Bubblechart** è una variante dello Scatterplot che introduce una dimensione visiva aggiuntiva ai dati. In questo tipo di grafico, la dimensione dei punti è proporzionale a una terza variabile, consentendo una visualizzazione più ricca e informativa.
#
# Per creare un Bubblechart utilizzando Plotly, possiamo partire da uno Scatterplot e specificare il parametro `size=` con la variabile che desideriamo utilizzare per determinare le dimensioni dei punti. Ad esempio, possiamo scegliere di utilizzare la lunghezza del petalo ('petal_length') come variabile per la dimensione dei punti.
#
# Questo ci permette di esplorare la relazione tra due variabili, come la larghezza e la lunghezza dei sepali, mentre aggiungiamo un ulteriore livello di dettaglio attraverso la dimensione dei punti, che riflette la terza variabile scelta. Utilizzando Plotly, possiamo creare facilmente Bubblechart interattivi che forniscono una panoramica chiara e dettagliata dei dati.

# %%
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", size='petal_length', width=1000, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Un Bubblechart può risultare utile quando vogliamo rappresentare, ad esempio:
#
# - **Popolazione delle città in base all'area e alla densità abitativa**:
#
#   In un dataset che contiene informazioni sulle città, inclusi la loro area geografica, la popolazione e la densità abitativa, un Bubblechart può essere utilizzato per visualizzare la relazione tra l'area della città (sull'asse x), la popolazione (sull'asse y) e la densità abitativa (dimensione dei punti). Ogni punto nel grafico rappresenta una città, dove la dimensione dei punti indica la densità abitativa. Questo Bubblechart consente di identificare facilmente le città con una popolazione elevata e una densità abitativa più concentrata.
#
# - **Vendite di prodotti in base al prezzo e alla quantità venduta**:
#
#   In un dataset relativo alle vendite di prodotti contenente informazioni sui prezzi dei prodotti, le quantità vendute e il fatturato generato da ciascun prodotto, un Bubblechart può essere utilizzato per visualizzare la relazione tra il prezzo del prodotto (sull'asse x), la quantità venduta (sull'asse y) e il fatturato generato (dimensione dei punti). Ogni punto nel grafico rappresenta un prodotto, dove la dimensione dei punti indica il fatturato generato. Questo Bubblechart consente di identificare facilmente i prodotti con vendite elevate e/o un prezzo elevato.
#
# - **Performance degli studenti in base al tempo di studio e al punteggio degli esami**:
#
#   In un dataset che contiene informazioni sul tempo medio di studio settimanale, i punteggi degli esami e il livello di soddisfazione degli studenti, un Bubblechart può essere utilizzato per visualizzare la relazione tra il tempo di studio (sull'asse x), il punteggio degli esami (sull'asse y) e il livello di soddisfazione (dimensione dei punti). Ogni punto nel grafico rappresenta uno studente, dove la dimensione dei punti indica il livello di soddisfazione. Questo Bubblechart consente di identificare facilmente gli studenti che ottengono punteggi elevati negli esami e che sono soddisfatti del loro tempo di studio.

# %% [markdown]
# ## Esercizio 1

# %% [markdown]
# Caricare il dataset "penguin_size.csv" e creare uno scatterplot che mostri il rapporto tra lunghezza (`culmen_lenghth`) e profodità del becco (`culmen_depth`).
#
# I punti dello scatterplot devono essere colorati per tipo di specie del pinguino.

# %%
import pandas as pd
df_path = "https://github.com/Cinofix/analisi-e-rappresentazione-dati/raw/main/data/penguins_size.csv"

df = pd.read_csv(df_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   culmen_length_mm   342 non-null    float64
#  3   culmen_depth_mm    342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                334 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %%
fig = px.scatter(df, x='culmen_length_mm', y='culmen_depth_mm', color='species',
                 title='Scatterplot di lunghezza e profondità del becco',
                 width=1000, height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Esercizio 2

# %% [markdown]
# Caricare il dataset "dipendenti.csv" e creare uno scatterplot di salario rispetto all'età.
#
# Colorare i punti dello scatterplot a seconda se l'informazione è verificata oppure no. Creare poi un secondo scatterplot cambiando i colori in base alla regione di provenienza.

# %%
df_path = "https://github.com/Cinofix/analisi-e-rappresentazione-dati/raw/main/data/dipendenti.csv"

df = pd.read_csv(df_path)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          1000 non-null   int64
#  1   Nome        977 non-null    object
#  2   Età         928 non-null    float64
#  3   Regione     854 non-null    object
#  4   Salario     905 non-null    float64
#  5   Verificato  949 non-null    object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 47.0+ KB

# %%
# Creazione dello Scatterplot con Plotly Express
fig = px.scatter(df, x='Età', y='Salario', color='Verificato', title='Scatterplot di salario rispetto all\'età', width=1000, height=500)

# Mostrare il grafico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Creazione dello Scatterplot con Plotly Express
fig = px.scatter(df, x='Età', y='Salario', color='Regione', title='Scatterplot di salario rispetto all\'età', width=1000, height=500)

# Mostrare il grafico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Esercizio 3

# %% [markdown]
# Aggiungere l'informazione del peso corporeo (`body_mass_g`) al grafico di 'Esercizio 1' per trasformare il grafico in un Bubblechart.
#
# NB: Potrebbe essere necessario rimuovere i valori nulli.

# %%
df_path = "https://github.com/Cinofix/analisi-e-rappresentazione-dati/raw/main/data/penguins_size.csv"

df = pd.read_csv(df_path)

# %%
fig = px.scatter(df, x='culmen_length_mm', y='culmen_depth_mm', color='species', size="body_mass_g",
                 title='Bubblechart di lunghezza e profondità del becco correlata alla massa corporea',
                 width=1200, height=500)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-2f46276088d9> in <cell line: 1>()
# ----> 1 fig = px.scatter(df, x='culmen_length_mm', y='culmen_depth_mm', color='species', size="body_mass_g",
#       2                  title='Bubblechart di lunghezza e profondità del becco correlata alla massa corporea',
#       3                  width=1200, height=500)
#       4 fig.show()
#
# ...

# %%
df.dropna(inplace=True)

# %%
fig = px.scatter(df, x='culmen_length_mm', y='culmen_depth_mm', color='species', size="body_mass_g",
                 title='Bubblechart di lunghezza e profondità del becco correlata alla massa corporea',
                 width=1200, height=500)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
#  # Linechart

# %% [markdown]
# Il Linechart è una rappresentazione visiva dei dati attraverso una serie di punti connessi da linee rette. È comunemente utilizzato per mostrare le tendenze temporali dei dati, come l'andamento delle vendite nel corso del tempo o l'evoluzione di un fenomeno nel corso degli anni.
#
# Tre esempi di utilizzo del Linechart per rappresentare tendenze temporali sono:
#
# - **Andamento delle vendite nel corso del tempo**:
#
#   In un dataset relativo alle vendite di un'azienda nel corso degli anni, un Linechart può essere utilizzato per visualizzare l'andamento delle vendite nel tempo. Ogni punto nel grafico rappresenta una specifica data, mentre le linee rette connettono i punti per mostrare l'evoluzione delle vendite nel tempo. Questo Linechart consente di identificare facilmente le variazioni stagionali o le tendenze di crescita o decrescita delle vendite nel corso degli anni.
#
# - **Evoluzione del prezzo delle azioni nel corso del tempo**:
#
#   In un dataset contenente i prezzi storici delle azioni di una società quotata in borsa, un Linechart può essere utilizzato per visualizzare l'andamento del prezzo delle azioni nel corso del tempo. Ogni punto nel grafico rappresenta una specifica data, mentre le linee rette connettono i punti per mostrare l'evoluzione del prezzo delle azioni nel tempo. Questo Linechart consente agli investitori di monitorare le fluttuazioni del prezzo delle azioni e identificare eventuali trend o pattern.
#
# - **Trend delle temperature medie mensili nel corso dell'anno**:
#
#   In un dataset meteorologico contenente le temperature medie mensili di una determinata località nel corso degli anni, un Linechart può essere utilizzato per visualizzare il trend delle temperature nel corso dell'anno. Ogni punto nel grafico rappresenta un mese dell'anno, mentre le linee rette connettono i punti per mostrare il trend delle temperature nel corso degli anni. Questo Linechart consente di identificare facilmente le variazioni stagionali delle temperature e di valutare eventuali cambiamenti nel clima nel corso del tempo.

# %% [markdown]
# Per creare un [linechart](https://plotly.com/python/line-charts/) utilizziamo `px.line()`.
#
# Utilizziamo il dataset **gapminder**.
#
# Il dataset Gapminder è un famoso insieme di dati che contiene informazioni socio-economiche su diverse nazioni del mondo, suddivise per anni. Ogni riga del dataset rappresenta una nazione in un determinato anno e include una serie di variabili, come il reddito pro capite, l'aspettativa di vita, il tasso di fertilità e altre metriche socio-economiche.
#
# Questo dataset è ampiamente utilizzato per analizzare le tendenze globali nel corso del tempo e per esplorare le relazioni tra variabili socio-economiche. La sua struttura tabellare lo rende adatto per l'analisi statistica e la visualizzazione dei dati attraverso diversi tipi di grafici.
#
# Per creare un linechart utilizzando Plotly, possiamo sfruttare la funzione px.`line()` fornita da Plotly Express. Questa funzione ci consente di creare facilmente grafici a linea utilizzando i dati del dataset Gapminder. Possiamo tracciare, ad esempio, l'andamento nel tempo dell'aspettativa di vita, del reddito pro capite o di qualsiasi altra variabile presente nel dataset, suddividendo le linee per nazione.

# %%
df = px.data.gapminder()

df_europe = df[df["continent"] =="Europe"]
df_europe_sub = df_europe[df_europe["country"].isin(["Italy", "France", "Germany", "Spain"])]

df_europe_sub.head(4)
# Out:
#     country continent  year  lifeExp       pop     gdpPercap iso_alpha  \
# 528  France    Europe  1952    67.41  42459667   7029.809327       FRA
# 529  France    Europe  1957    68.93  44310863   8662.834898       FRA
# 530  France    Europe  1962    70.51  47124000  10560.485530       FRA
# 531  France    Europe  1967    71.55  49569000  12999.917660       FRA
#
#      iso_num
# 528      250
# 529      250
# 530      250
# 531      250

# %%
fig = px.line(df_europe_sub, x='year', y='lifeExp', color='country', width=800, height=450)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Per aiutarci con le funzioni interattive del grafico possiamo specificare `markers=True` in maniera tale da evidenziare le nostre osservazioni.

# %%
fig = px.line(df_europe_sub, x='year', y='lifeExp', color='country', markers=True, width=800, height=450)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 1. `df_europe_sub`: DataFrame contenente i dati per il grafico.
# 2. `x='year'`: Colonna del DataFrame usata sull'asse delle ascisse.
# 3. `y='lifeExp'`: Colonna del DataFrame usata sull'asse delle ordinate.
# 4. `color='country'`: Colonna del DataFrame usata per colorare le linee del grafico.
# 5. `markers=True`: Specifica se mostrare o meno i marker (punti) sui punti di dati nel grafico a linee.

# %% [markdown]
# In ogni plot possiamo andare a personalizzare i nomi degli assi tramite il parametro `labels=`, esso vuole in input un dizionario che mappa il vecchio nome con il nuovo.

# %%
fig = px.line(df_europe_sub, x='year', y='lifeExp', color='country', markers=True, labels={"year":"Anni","lifeExp":"Aspettativa di vita"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.line(df_europe_sub, x='year', y='lifeExp', color='country', symbol='country',
              width=800, height=500,
              labels={"year":"Anni","lifeExp":"Aspettativa di vita"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Esercizio 4

# %% [markdown]
# Caricare il dataset di plotly `stocks()` che contiene informazioni riguardo gli andamenti di mercato di alcuni indici.
#
# Scegliere 2 di questi indici e raffigurarli con un linechart.
#
# PS: possiamo passare come valore del parametro `y=` una lista con un **subset** di colonne.

# %% [markdown]
# Le colonne nel dataframe "Stocks" rappresentano i dati relativi ai prezzi delle azioni di diverse società quotate in borsa. Ecco una descrizione delle colonne:
#
# - **date**: Questa colonna contiene le date per le quali sono registrati i dati relativi ai prezzi delle azioni. Ogni riga del dataframe corrisponde a una specifica data.
# - **GOOG**: Questa colonna rappresenta i prezzi delle azioni della società Google (simbolo ticker: GOOG) per le date corrispondenti. Ogni valore nella colonna rappresenta il prezzo delle azioni di Google per una specifica data.
# - **AAPL**: Questa colonna rappresenta i prezzi delle azioni della società Apple Inc. (simbolo ticker: AAPL) per le date corrispondenti. Ogni valore nella colonna rappresenta il prezzo delle azioni di Apple per una specifica data.
# - **AMZN**: Questa colonna rappresenta i prezzi delle azioni della società Amazon.com Inc. (simbolo ticker: AMZN) per le date corrispondenti. Ogni valore nella colonna rappresenta il prezzo delle azioni di Amazon per una specifica data.
# - **FB**: Questa colonna rappresenta i prezzi delle azioni della società Meta Platforms Inc. (precedentemente nota come Facebook Inc., simbolo ticker: FB) per le date corrispondenti. Ogni valore nella colonna rappresenta il prezzo delle azioni di Meta Platforms per una specifica data.
# - **NFLX**: Questa colonna rappresenta i prezzi delle azioni della società Netflix Inc. (simbolo ticker: NFLX) per le date corrispondenti. Ogni valore nella colonna rappresenta il prezzo delle azioni di Netflix per una specifica data.
# - **MSFT**: Questa colonna rappresenta i prezzi delle azioni della società Microsoft Corporation (simbolo ticker: MSFT) per le date corrispondenti. Ogni valore nella colonna rappresenta il prezzo delle azioni di Microsoft per una specifica data.
#
# In sintesi, il dataframe "Stocks" contiene i prezzi storici delle azioni di alcune delle principali società tecnologiche quotate in borsa, rappresentati per ogni data nel periodo di interesse.

# %%
df = px.data.stocks()

df.head()
# Out:
#          date      GOOG      AAPL      AMZN        FB      NFLX      MSFT
# 0  2018-01-01  1.000000  1.000000  1.000000  1.000000  1.000000  1.000000
# 1  2018-01-08  1.018172  1.011943  1.061881  0.959968  1.053526  1.015988
# 2  2018-01-15  1.032008  1.019771  1.053240  0.970243  1.049860  1.020524
# 3  2018-01-22  1.066783  0.980057  1.140676  1.016858  1.307681  1.066561
# 4  2018-01-29  1.008773  0.917143  1.163374  1.018357  1.273537  1.040708

# %%
fig = px.line(df, x='date', y=["GOOG", "AAPL"], width=800, height=450,
              labels={"date":"Anni","value":"Valore azionario in $", "variable":"Azienda"},
              title="Google vs Apple")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Esercizio 5

# %% [markdown]
# Prendere il dataset `gapminder()` e rappresentare l'andamento delle aspettative di vita di 4 nazioni asiatiche.
#
# > Add blockquote

# %%
df = px.data.gapminder()

df_asia = df[df["continent"] =="Asia"]
print(df_asia['country'].unique())

df_asia_sub=df_asia[df_asia["country"].isin(["Vietnam", "Thailand", "China", "Japan"])]

df_asia_sub.head(4)
# Out:
# ['Afghanistan' 'Bahrain' 'Bangladesh' 'Cambodia' 'China'
#  'Hong Kong, China' 'India' 'Indonesia' 'Iran' 'Iraq' 'Israel' 'Japan'
#  'Jordan' 'Korea, Dem. Rep.' 'Korea, Rep.' 'Kuwait' 'Lebanon' 'Malaysia'
#  'Mongolia' 'Myanmar' 'Nepal' 'Oman' 'Pakistan' 'Philippines'
#  'Saudi Arabia' 'Singapore' 'Sri Lanka' 'Syria' 'Taiwan' 'Thailand'
#  'Vietnam' 'West Bank and Gaza' 'Yemen, Rep.']
#     country continent  year   lifeExp        pop   gdpPercap iso_alpha  \
# 288   China      Asia  1952  44.00000  556263527  400.448611       CHN
# 289   China      Asia  1957  50.54896  637408000  575.987001       CHN
# 290   China      Asia  1962  44.50136  665770000  487.674018       CHN
# 291   China      Asia  1967  58.38112  754550000  612.705693       CHN
#
#      iso_num
# 288      156
# 289      156
# 290      156
# 291      156

# %%
fig = px.line(df_asia_sub, x='year', y='lifeExp', color='country', markers=True, labels={"year":"Anni","lifeExp":"Aspettativa di vita"},
              width=800, height=450)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Lezione Plotly 2

# %% [markdown]
# # Piechart

# %% [markdown]
# Il Piechart è una rappresentazione circolare in cui il cerchio è diviso in fette, o "spicchi", le cui aree sono proporzionali ai valori che rappresentano. È comunemente utilizzato per mostrare la distribuzione percentuale di categorie o componenti all'interno di un insieme di dati, come la suddivisione del budget tra diverse voci di spesa o la quota di mercato delle diverse aziende in un settore.
#
# Ecco 3 esempi di utilizzo del Piechart:
#
# - **Suddivisione del budget tra diverse voci di spesa**:
#
# Immagina di dover rappresentare la suddivisione del budget mensile di una famiglia tra diverse voci di spesa come affitto, cibo, trasporti e intrattenimento. Il Piechart può essere utilizzato per mostrare la percentuale di budget dedicata a ciascuna voce di spesa, consentendo una rapida comprensione della distribuzione del budget complessivo.
#
# - **Quota di mercato delle diverse aziende in un settore**:
#
#   Nel contesto di un settore industriale, come quello dell'informatica, il Piechart può essere impiegato per visualizzare la quota di mercato delle diverse aziende, come A, B, C e D. Questo permette di avere una panoramica immediata della distribuzione del mercato tra i concorrenti principali.
#
# - **Distribuzione percentuale dei voti in un'elezione**:
#
#   Durante un'elezione politica, il Piechart può essere utilizzato per mostrare la distribuzione percentuale dei voti tra i vari candidati, come A, B, C e D. Questo tipo di visualizzazione fornisce una chiara rappresentazione della preferenza e della percentuale di sostegno per ciascun candidato.

# %% [markdown]
# Prediamo come riferimento il dataset `tips` dove ogni riga del dataset è uno scontrino.

# %%
df = px.data.tips()
fig = px.pie(df, values='tip', names='day')
fig.show()

# %% [markdown]
# # Barchart

# %% [markdown]
# Il Barchart è un tipo di grafico che utilizza barre rettangolari orizzontali o verticali per rappresentare i dati. È efficace nel confrontare quantità tra diverse categorie o gruppi di dati, come le vendite per categoria di prodotto o il numero di studenti per fascia d'età in una classe.
#
# Alcuni esempi sono:
#
# - **Vendite per categoria di prodotto**:
#
#   In un dataset relativo alle vendite di un negozio al dettaglio, un Barchart può essere utilizzato per visualizzare le vendite per categoria di prodotto. Ogni barra rappresenta una categoria di prodotto (ad esempio, abbigliamento, elettronica, alimentari) e l'altezza della barra corrisponde al valore delle vendite in quella categoria. Questo permette di confrontare facilmente le vendite tra diverse categorie di prodotti.
#
# - **Numero di studenti per fascia d'età in una classe**:
#
#   In un dataset relativo agli studenti di una scuola, un Barchart può essere utilizzato per visualizzare il numero di studenti per fascia d'età all'interno di una classe. Ogni barra rappresenta una fascia d'età (ad esempio, 6-10 anni, 11-15 anni, 16-18 anni) e l'altezza della barra corrisponde al numero di studenti in quella fascia d'età. Questo permette di visualizzare facilmente la distribuzione di età degli studenti in una classe.
#
# - **Performance dei dipendenti per dipartimento**:
#
#   In un dataset relativo alle performance dei dipendenti di un'azienda, un Barchart può essere utilizzato per visualizzare le performance per dipartimento. Ogni barra rappresenta un dipartimento (ad esempio, vendite, marketing, risorse umane) e l'altezza della barra corrisponde al valore delle performance in quel dipartimento. Questo permette di confrontare facilmente le performance tra diversi dipartimenti dell'azienda.

# %% [markdown]
# Possiamo creare un [barchart](https://plotly.com/python/bar-charts/) utilizzando `px.bar()`.
#
# **NB:** Utilizzando px.bar ogni riga del dataframe rappresenta un rettangolo.

# %%
data_canada = px.data.gapminder().query("country == 'Canada'")
fig = px.bar(data_canada, x='year', y='pop')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Anche nei barchart possiamo specificare una terza variabile utilizzando `color=` per aggiungere informazioni al grafico.

# %%
fig = px.bar(data_canada, x='year', y='pop',color='lifeExp')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Histogram

# %% [markdown]
# L'Istogramma è una visualizzazione che rappresenta la distribuzione di una singola variabile numerica suddividendola in intervalli (bin) e mostrando la frequenza o la densità di osservazioni in ciascun intervallo. È utilizzato per esaminare la forma e la distribuzione dei dati e identificare eventuali modelli o anomalie.
#
# Potrebbe risultare utile quando vogliamo rappresentare:
#
# - **Distribuzione delle altezze in una popolazione**:
#
#   In un dataset contenente le altezze di una popolazione, un istogramma può essere utilizzato per visualizzare la distribuzione delle altezze. Le barre dell'istogramma rappresentano gli intervalli di altezza (bin), mentre l'altezza delle barre rappresenta la frequenza delle osservazioni in ciascun intervallo. Questo permette di identificare facilmente la distribuzione delle altezze all'interno della popolazione e di individuare eventuali tendenze o modelli.
#
# - **Distribuzione dei voti in un esame**:
#
#   In un dataset relativo ai voti ottenuti dagli studenti in un esame, un istogramma può essere utilizzato per visualizzare la distribuzione dei voti. Le barre dell'istogramma rappresentano gli intervalli di voto (bin), mentre l'altezza delle barre rappresenta la frequenza delle osservazioni in ciascun intervallo. Questo permette di valutare la distribuzione dei voti degli studenti e di identificare eventuali anomalie o tendenze nella performance degli studenti.
#
# - **Distribuzione dei redditi in una città**:
#
#   In un dataset contenente i redditi degli abitanti di una città, un istogramma può essere utilizzato per visualizzare la distribuzione dei redditi. Le barre dell'istogramma rappresentano gli intervalli di reddito (bin), mentre l'altezza delle barre rappresenta la frequenza delle osservazioni in ciascun intervallo. Questo permette di esaminare la distribuzione dei redditi nella città e di identificare eventuali disparità socioeconomiche o tendenze nella distribuzione dei redditi.

# %% [markdown]
# # Tables
